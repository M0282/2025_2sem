# %%
import sys , os

# %%
sys.path.append(os.path.join(os.path.dirname(__file__),'..'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sys.path.append(os.path.join(os.path.dirname(__file__),'..'))
#
# NameError: name '__file__' is not defined

# %%
from dataset.mnist
