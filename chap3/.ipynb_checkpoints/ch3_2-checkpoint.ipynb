# %%
import numpy as np

# %%
A= np.array([1,2,3,4])

# %%
print(A)
# Out:
# [1 2 3 4]

# %%
np.ndim(A)
# Out:
# 1

# %%
A.shape
# Out:
# (4,)

# %%
A.shape[0]
# Out:
# 4

# %%
B=np.array([[1,2],[3,4],[5,6]])
print(B)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
np.ndim(B)
# Out:
# 2

# %%
B.shape
# Out:
# (3, 2)

# %%
#행렬의 곱

# %%
a=np.array([[1,2],[3,4]])
a.shape
# Out:
# (2, 2)

# %%
b=np.array([[5,6],[7,8]])
b.shape
# Out:
# (2, 2)

# %%
np.dot(a,b)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
#행렬곱에 맞는 연산만을 수행 가능
